# %%
from pathlib import Path

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
zarr_path = Path("..") / "output" / "pyqg_128_reference.zarr"
ds = xr.open_zarr(zarr_path)
ds
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:            (time: 1, l: 128, k: 65, lev: 2, y: 128, x: 128,
#                         lev_mid: 1)
# Coordinates:
#   * time               (time) float64 8B 3.11e+08
#   * l                  (l) float64 1kB 0.0 6.283e-06 ... -1.257e-05 -6.283e-06
#   * k                  (k) float64 520B 0.0 6.283e-06 ... 0.0003958 0.0004021
#   * lev                (lev) int64 16B 1 2
#   * y                  (y) float64 1kB 3.906e+03 1.172e+04 ... 9.961e+05
#   * x                  (x) float64 1kB 3.906e+03 1.172e+04 ... 9.961e+05
#   * lev_mid            (lev_mid) float64 8B 1.5
# Data variables: (12/32)
#     APEflux            (time, l, k) float64 67kB ...
#     APEgen             (time) float64 8B ...
#     APEgenspec         (time, l, k) float64 67kB ...
#     Dissspec           (time, l, k) float64 67kB ...
#     dqdt               (time, lev, y, x) float64 262kB ...
#     dqhdt              (time, lev, l, k) complex128 266kB ...
# ...

# %%
ds["k"].shape
# Out:
# (65,)

# %%
ds["KEspec"].isel(lev=0)
# Out:
# <xarray.DataArray 'KEspec' (time: 1, l: 128, k: 65)> Size: 67kB
# [8320 values with dtype=float64]
# Coordinates:
#   * time     (time) float64 8B 3.11e+08
#   * l        (l) float64 1kB 0.0 6.283e-06 1.257e-05 ... -1.257e-05 -6.283e-06
#   * k        (k) float64 520B 0.0 6.283e-06 1.257e-05 ... 0.0003958 0.0004021
#     lev      int64 8B 1
# Attributes:
#     long_name:  kinetic energy spectrum
#     units:      m^2 s^-2
